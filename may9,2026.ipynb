# %% [markdown]
# <a href="https://colab.research.google.com/github/k1a2v3i4/Java-Serialization-Demo/blob/main/may9%2C2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "name":["kav","Alice"],
    "rollno" : [12,13]
}
d=pd.DataFrame(data)

print(d[d["rollno"]>12])
# Out:
#     name  rollno
# 1  Alice      13
